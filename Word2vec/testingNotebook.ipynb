# %%
# This notebook is for testing de dataset

# %%
tokens = list()
with open("/workspaces/JetBrains-Internship-Application/Word2vec/Data/cured_data", "r") as data:
    for i in data.read().split(" "):
        tokens.append(i)
print(*tokens, sep = "\n")

# %%
unique_tokens = set(tokens)

# %%
print(unique_tokens)

# %%
print(f"unique_tokens: {len(unique_tokens)}/{len(tokens)}")
print(f"longest_word: {max(unique_tokens, key=len)}")

# %%
import src.indexer as id

indexer = id.Indexer()
indexer.index_loader("/workspaces/JetBrains-Internship-Application/Word2vec/Data/tokens_index")
for i in [6307, 45616, 36354, 9439, 32515]:
    print(indexer.getToken(i))
# Out:
# prospects
# and
# picks
# leading
# draft
