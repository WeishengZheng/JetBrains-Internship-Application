# %%
# This notebook is for testing de dataset

# %%
tokens = list()
with open("/workspaces/JetBrains-Internship-Application/Word2vec/Data/cured_data", "r") as data:
    for i in data.read().split(" "):
        tokens.append(i)
print(*tokens, sep = "\n")

# %%
unique_tokens = set(tokens)

# %%
print(unique_tokens)

# %%
print(f"unique_tokens: {len(unique_tokens)}/{len(tokens)}")
print(f"longest_word: {max(unique_tokens, key=len)}")

# %%
import src.process as pr

tokens = pr.load_tokenizer("/workspaces/JetBrains-Internship-Application/Word2vec/Data/cured_data")

print(tokens)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 3
#       1 import src.process as pr
# ----> 3 tokens = pr.load_tokenizer("/workspaces/JetBrains-Internship-Application/Word2vec/Data/cured_data")
#       5 print(tokens)
#
# File /workspaces/JetBrains-Internship-Application/Word2vec/src/process.py:35, in load_tokenizer(path)
#      33 def load_tokenizer(path : str) -> list:
#      34     with open(path, "r") as curedData:
# ---> 35         return curedData.read().split('\n').split(" ")
#
# AttributeError: 'list' object has no attribute 'split'
